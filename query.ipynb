# %%
import sqlite3

conn = sqlite3.connect("data/youtube_data.db")
cursor = conn.cursor()

def foo(query):
    cursor.execute(query)
    results = cursor.fetchall()

    for row in results:
       print(row)

# %%
# foo("SELECT name FROM sqlite_master WHERE type='table'")
foo("SELECT COUNT(*) FROM Videos")
# Out:
# (2647,)

# %%
conn.close()
